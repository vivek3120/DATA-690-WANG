# %%
import random

# 1. 10x10 matrix of random numbers
# --------------------------
for i in range(1,11):
    for j in range(1,11):
        print(random.randint(1,9),end=' ')
    print()
# -----------------------------

# 2.10x10 matrix but with @ in place of odd number
# --------------------
for i in range(1,11):
    for j in range(1,11):
        x = random.randint(1,9)
        if (x%2) != 0:
            x = '@' 
        print(x,end=' ')
    print()
# ----------------------

# 3. 10x10 matrix but with sum of each row
# ------------------------
for i in range(1,11):
    horizontal_sum = 0
    for j in range(1,11):
        x = random.randint(1,9)
        horizontal_sum += x
        print(x,end='  ')
    print('*',horizontal_sum)
# ------------------------


# 4. 10x10 matrix but with ***
# --------------------------
for i in range(1,13):
    horizontal_sum = 0
    for j in range(1,13):
        if i in (1,12): #printing a whole line of * characters
            print('*',end='  ')
        else:
            if j in (1,12):
                print('*',end='  ')
            else: #actual random numbers within the border of stars
                x = random.randint(1,9)
                print(x,end='  ')
    print()

#5. 10x10 matrix of random numbers with vertical and horizontal sum
# -----------------------------
vertical_sum = dict()
# this loop is for each row
for i in range(1,11):
    horizontal_sum = 0
    for j in range(1,11):
        x = random.randint(1,9)
        horizontal_sum += x
        if i in vertical_sum.keys():
            vertical_sum[i] += x  #stores sum of a column i in the dictionary
        else: #if the column number is not registered in the dictionary
            vertical_sum[i] = x
        print(x,end='   ')
    print('*',horizontal_sum)

for i in range(1,11):
    print('*   ',end='')
print()
    
for k in vertical_sum:
    print(vertical_sum[k],end='  ')
# ------------------------------
# Out:
# 7 3 1 9 9 7 4 9 8 5
# 3 5 8 1 7 4 8 8 3 2
# 2 8 7 6 7 8 8 2 2 2
# 4 6 5 3 2 8 7 3 1 1
# 8 2 8 6 7 6 7 4 8 6
# 7 4 5 6 8 2 3 4 1 3
# 8 9 5 5 3 8 8 6 8 5
# 1 6 8 6 1 8 6 6 1 4
# 3 4 4 9 7 4 4 3 9 1
# 5 4 7 1 3 8 7 1 8 3
# @ @ @ 6 @ @ @ 6 @ 2
# 6 @ @ @ 2 @ @ 8 @ 8
# @ 4 6 @ @ @ 2 @ @ 6
# @ @ @ @ @ 8 2 @ 6 2
# 4 @ @ 4 @ @ 6 @ @ 4
# 8 8 @ 6 2 @ @ 2 @ @
# @ @ @ @ 4 4 @ @ 8 @
# @ 8 @ @ @ 4 @ @ @ @
# 8 @ @ 2 @ 6 @ @ @ 8
# @ @ @ @ 2 @ 8 @ @ 2
# 6  2  7  3  6  4  7  4  7  3  * 49
# 7  4  6  7  4  2  7  2  2  3  * 44
# 5  9  9  7  8  1  3  2  3  5  * 52
# 3  4  3  1  9  7  4  2  1  6  * 40
# 8  7  2  7  3  1  5  1  2  9  * 45
# 8  9  7  3  8  6  4  6  2  7  * 60
# 6  2  2  2  2  3  4  4  3  6  * 34
# 4  2  8  5  6  8  6  5  9  7  * 60
# 6  1  7  4  1  8  5  8  3  9  * 52
# 8  6  2  8  4  9  5  7  6  6  * 61
# *  *  *  *  *  *  *  *  *  *  *  *
# *  3  7  7  3  5  7  3  7  8  7  *
# *  1  9  3  8  2  4  5  9  5  6  *
# *  9  8  8  7  3  8  1  3  3  6  *
# *  1  6  3  3  2  5  1  4  7  9  *
# *  2  7  3  1  2  4  4  3  3  7  *
# *  5  9  9  1  4  2  5  1  8  8  *
# *  5  7  5  3  7  8  6  5  2  3  *
# *  8  1  9  9  5  4  8  3  9  4  *
# *  8  3  3  1  6  2  1  2  3  4  *
# *  3  9  4  1  7  4  2  9  5  8  *
# *  *  *  *  *  *  *  *  *  *  *  *
# 9   7   7   4   1   3   6   7   4   5   * 53
# 5   6   4   4   1   8   3   7   2   5   * 45
# 1   1   9   9   8   7   9   9   1   4   * 58
# 5   4   7   3   1   2   4   9   7   2   * 44
# 2   5   2   9   4   8   6   6   5   5   * 52
# 7   4   4   9   6   8   6   3   5   5   * 57
# 3   7   2   6   3   4   6   3   6   1   * 41
# 7   8   7   7   3   1   5   1   1   3   * 43
# 1   6   1   9   8   8   5   4   8   7   * 57
# 6   4   8   4   9   7   9   6   3   3   * 59
# *   *   *   *   *   *   *   *   *   *
# 53  45  58  44  52  57  41  43  57  59
